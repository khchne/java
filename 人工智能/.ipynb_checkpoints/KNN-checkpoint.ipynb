# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import copy
import seaborn as sns

# %%
data = pd.read_csv('2.Financial Loan.csv')

# %%
data = data.drop("Id", axis=1)
data
# Out:
#          Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# 0       1303834   23           3         single          rented            no
# 1       7574516   40          10         single          rented            no
# 2       3991815   66           4        married          rented            no
# 3       6256451   41           2         single          rented           yes
# 4       5768871   47          11         single          rented            no
# ...         ...  ...         ...            ...             ...           ...
# 251995  8154883   43          13         single          rented            no
# 251996  2843572   26          10         single          rented            no
# 251997  4522448   46           7         single          rented            no
# 251998  6507128   45           0         single          rented            no
# 251999  9070230   70          17         single          rented            no
#
# ...

# %%
data_1 = copy.deepcopy(data)
data_2 = copy.deepcopy(data)

# %%
data_1 = data_1.drop('Married/Single', axis=1)
data_1 = data_1.drop('House_Ownership', axis=1)
data_1 = data_1.drop('Car_Ownership', axis=1)
data_1 = data_1.drop('Profession', axis=1)
data_1 = data_1.drop('CITY', axis=1)
data_1 = data_1.drop('STATE', axis=1)
data_1
# Out:
#          Income  Age  Experience  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  \
# 0       1303834   23           3                3                 13
# 1       7574516   40          10                9                 13
# 2       3991815   66           4                4                 10
# 3       6256451   41           2                2                 12
# 4       5768871   47          11                3                 14
# ...         ...  ...         ...              ...                ...
# 251995  8154883   43          13                6                 11
# 251996  2843572   26          10                6                 11
# 251997  4522448   46           7                7                 12
# 251998  6507128   45           0                0                 10
# 251999  9070230   70          17                7                 11
#
#         Risk_Flag
# 0               0
# 1               0
# 2               0
# 3               1
# 4               1
# ...           ...
# ...

# %%
sum(data_1['Risk_Flag'])/len(data_1)
# Out:
# 0.123

# %%
data_1 = data_1.sample(frac=0.05)

# %%
data_1
# Out:
#          Income  Age  Experience  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  \
# 151839  3753805   68           0                0                 13
# 106567    93648   34           3                3                 12
# 149169  7509022   75           7                7                 12
# 138491  6314607   50           9                9                 13
# 10213   1765870   39          11               11                 10
# ...         ...  ...         ...              ...                ...
# 114354  3679290   25           9                6                 11
# 63786   5278110   45          10                8                 10
# 62877   7396856   76           3                3                 10
# 38565   7625659   51           6                6                 12
# 163578  3915230   40          16               11                 14
#
#         Risk_Flag
# 151839          0
# 106567          0
# 149169          0
# 138491          0
# 10213           1
# ...           ...
# ...

# %%
data_1.dropna(axis=0,how='any')
# Out:
#          Income  Age  Experience  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  \
# 151839  3753805   68           0                0                 13
# 106567    93648   34           3                3                 12
# 149169  7509022   75           7                7                 12
# 138491  6314607   50           9                9                 13
# 10213   1765870   39          11               11                 10
# ...         ...  ...         ...              ...                ...
# 114354  3679290   25           9                6                 11
# 63786   5278110   45          10                8                 10
# 62877   7396856   76           3                3                 10
# 38565   7625659   51           6                6                 12
# 163578  3915230   40          16               11                 14
#
#         Risk_Flag
# 151839          0
# 106567          0
# 149169          0
# 138491          0
# 10213           1
# ...           ...
# ...

# %%
data_1['Risk_Flag'] = data_1['Risk_Flag'].map(lambda x: False if x==None  else bool(x))
data_1
# Out:
#          Income  Age  Experience  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  \
# 151839  3753805   68           0                0                 13
# 106567    93648   34           3                3                 12
# 149169  7509022   75           7                7                 12
# 138491  6314607   50           9                9                 13
# 10213   1765870   39          11               11                 10
# ...         ...  ...         ...              ...                ...
# 114354  3679290   25           9                6                 11
# 63786   5278110   45          10                8                 10
# 62877   7396856   76           3                3                 10
# 38565   7625659   51           6                6                 12
# 163578  3915230   40          16               11                 14
#
#         Risk_Flag
# 151839      False
# 106567      False
# 149169      False
# 138491      False
# 10213        True
# ...           ...
# ...

# %%
cov = data_1.corr()

# %%
cov
# Out:
#                      Income       Age  Experience  CURRENT_JOB_YRS  \
# Income             1.000000  0.010131    0.003475         0.007654
# Age                0.010131  1.000000    0.008966         0.006465
# Experience         0.003475  0.008966    1.000000         0.640323
# CURRENT_JOB_YRS    0.007654  0.006465    0.640323         1.000000
# CURRENT_HOUSE_YRS  0.004852 -0.016056    0.008974        -0.001007
# Risk_Flag         -0.019877 -0.023394   -0.034509        -0.004494
#
#                    CURRENT_HOUSE_YRS  Risk_Flag
# Income                      0.004852  -0.019877
# Age                        -0.016056  -0.023394
# Experience                  0.008974  -0.034509
# CURRENT_JOB_YRS            -0.001007  -0.004494
# CURRENT_HOUSE_YRS           1.000000   0.000034
# Risk_Flag                   0.000034   1.000000

# %%
sns.heatmap(cov, annot=True, vmax=1, square=True, cmap="rainbow")

# %%
data_1 = data_1.values[:1000]

# %%
n = len(data_1)//4

# %%
test_set = data_1[:n]
train_set = data_1[n:]

# %%
train_set
# Out:
# array([[8078779, 66, 9, 5, 14, False],
#        [2442178, 34, 15, 10, 13, True],
#        [7706206, 54, 13, 5, 11, False],
#        ...,
#        [682554, 57, 9, 9, 14, False],
#        [1606109, 42, 3, 3, 13, False],
#        [2810048, 79, 7, 7, 13, False]], dtype=object)

# %%
def distance(d1, d2):
    return sum((d1 - d2)**2)**0.5

# %%
def knn(data, k):
    res = [
        {"result":train[-1], "distance":distance(data[:-1], train[:-1])} for train in train_set
    ]
#     print(res)

    res = sorted(res, key=lambda items: items["distance"])
    res2 = res[:k]
#     print(res2)
    result = {True: 0, False: 0}
    sum = 0
    
    for r in res2:
        sum += r['distance']
    if sum == 0:
        return True
#     print(result[False])
#     print(sum)
    for r in res2:
#         print(r['result'])
#         print(result[r['result']])
        result[r['result']] += 1 - r['distance'] / sum
#         print("\n--> r = {} \n result[r['result']] = {}\n".format(r, result[r['result']]))
    
#     print(result)
#     print(data[-1])
#     return result
    if result[True]>result[False]:
        return True
    else:
        return False

# %%
knn(test_set[0], 5)
# Out:
# False

# %%
correctRate = 0
corrNum = 0
for i in test_set:
    res = knn(i, 5)
    if res == i[-1]:
        corrNum+=1
correctRate = 100*corrNum/len(test_set)

# %%
correctRate
# Out:
# 87.6

# %%
corrRateList = []
x = list(range(1,20,2))
for k in range(1, 20, 2):
    correctRate = 0
    corrNum = 0
    for i in test_set:
        res = knn(i, k)
        if res == i[-1]:
            corrNum+=1
    correctRate = 100*corrNum/len(test_set)
    corrRateList.append(correctRate)

# %%
plt.plot(x, corrRateList)
x = MultipleLocator(2)
# 设置刻度间隔
ax = plt.gca()
ax.xaxis.set_major_locator(x)
plt.xlim([0, 20])
plt.ylabel("Correct Rate: %")
plt.xlabel("The num of K")
plt.show()

# %%
# x = list(range(1,20,2))
# x

# %%
corrRateList = []
x = list(range(1,int(len(test_set)*0.9),2))
for k in range(1, int(len(test_set)*0.9), 2):
    correctRate = 0
    corrNum = 0
    for i in test_set:
        res = knn(i, k)
        if res == i[-1]:
            corrNum+=1
    correctRate = 100*corrNum/len(test_set)
    corrRateList.append(correctRate)
#     print("\nwhen the k is {}, using knn the correct rate is {:.3f}%\n".format(k, correctRate))

# %%
plt.plot(x, corrRateList)
plt.ylabel("Correct Rate: %")
plt.xlabel("The num of K")
plt.show()

# %%
data_2
# Out:
#          Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# 0       1303834   23           3         single          rented            no
# 1       7574516   40          10         single          rented            no
# 2       3991815   66           4        married          rented            no
# 3       6256451   41           2         single          rented           yes
# 4       5768871   47          11         single          rented            no
# ...         ...  ...         ...            ...             ...           ...
# 251995  8154883   43          13         single          rented            no
# 251996  2843572   26          10         single          rented            no
# 251997  4522448   46           7         single          rented            no
# 251998  6507128   45           0         single          rented            no
# 251999  9070230   70          17         single          rented            no
#
# ...

# %%
data_2 = data_2.drop("Profession",axis=1).drop('CITY',axis=1).drop("STATE", axis=1)

# %%
data_2
# Out:
#          Income  Age  Experience Married/Single House_Ownership Car_Ownership  \
# 0       1303834   23           3         single          rented            no
# 1       7574516   40          10         single          rented            no
# 2       3991815   66           4        married          rented            no
# 3       6256451   41           2         single          rented           yes
# 4       5768871   47          11         single          rented            no
# ...         ...  ...         ...            ...             ...           ...
# 251995  8154883   43          13         single          rented            no
# 251996  2843572   26          10         single          rented            no
# 251997  4522448   46           7         single          rented            no
# 251998  6507128   45           0         single          rented            no
# 251999  9070230   70          17         single          rented            no
#
# ...

# %%
data_2['Married/Single'] = data_2['Married/Single'].map(lambda x: 0 if x=='single'  else 1)
data_2['House_Ownership'] = data_2['House_Ownership'].map(lambda x: 0 if x=='rented'  else 1 if x=='norent_noown' else 2)
data_2['Car_Ownership'] = data_2['Car_Ownership'].map(lambda x: 1 if x=='yes'  else 0)
data_2
# Out:
#          Income  Age  Experience  Married/Single  House_Ownership  \
# 0       1303834   23           3               0                0
# 1       7574516   40          10               0                0
# 2       3991815   66           4               1                0
# 3       6256451   41           2               0                0
# 4       5768871   47          11               0                0
# ...         ...  ...         ...             ...              ...
# 251995  8154883   43          13               0                0
# 251996  2843572   26          10               0                0
# 251997  4522448   46           7               0                0
# 251998  6507128   45           0               0                0
# 251999  9070230   70          17               0                0
#
#         Car_Ownership  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  Risk_Flag
# 0                   0                3                 13          0
# ...

# %%
# data_2.drop_duplicates(subset='Car_Ownership',keep='first',inplace=True)
# data_2

# %%
data_2 = data_2.sample(frac=0.05)
data_2
# Out:
#          Income  Age  Experience  Married/Single  House_Ownership  \
# 126326  9959440   78          17               0                0
# 235108  5679523   43           8               0                0
# 132570  3735931   69          15               0                0
# 101174   874023   41          18               0                0
# 141277  5221691   42          17               0                0
# ...         ...  ...         ...             ...              ...
# 34687   7919486   36          12               0                0
# 215807  3160585   42          10               0                0
# 219757   772164   66          13               0                2
# 212669  4041403   47          19               0                0
# 74061    296613   23           3               0                0
#
#         Car_Ownership  CURRENT_JOB_YRS  CURRENT_HOUSE_YRS  Risk_Flag
# 126326              1                9                 13          0
# ...

# %%
cov = data_2.corr()

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(cov, annot=True, fmt='.3f', vmax=1, square=True, cmap="rainbow")

# %%
data_2 = data_2.values[:5000]

# %%
n = len(data_2)//4

# %%
test_set_2 = data_2[:n]
train_set_2 = data_2[n:]
test_set_2
# Out:
# array([[9959440,      78,      17, ...,       9,      13,       0],
#        [5679523,      43,       8, ...,       8,      11,       0],
#        [3735931,      69,      15, ...,      14,      13,       0],
#        ...,
#        [7090163,      52,      17, ...,       7,      11,       0],
#        [8550948,      45,      11, ...,      11,      11,       0],
#        [8996641,      75,      12, ...,      12,      13,       0]],
#       dtype=int64)

# %%
def knn2(data, k):
    res = [
        {"result":train[-1], "distance":distance(data[:-1], train[:-1])} for train in train_set_2
    ]
#     print(res)

    res = sorted(res, key=lambda items: items["distance"])
    res2 = res[:k]
#     print(res2)
    result = {True: 0, False: 0}
    sum = 0
    
    for r in res2:
        sum += r['distance']
    if sum == 0:
        return True
#     print(result[False])
#     print(sum)
    for r in res2:
#         print(r['result'])
#         print(result[r['result']])
        result[r['result']] += 1 - r['distance'] / sum
#         print("\n--> r = {} \n result[r['result']] = {}\n".format(r, result[r['result']]))
    
#     print(result)
#     print(data[-1])
#     return result
    if result[True]>result[False]:
        return True
    else:
        return False

# %%
correctRate = 0
corrNum = 0
for i in test_set_2:
    res = knn2(i, 5)
    if res == i[-1]:
        corrNum+=1
correctRate = 100*corrNum/len(test_set_2)

# %%
correctRate
# Out:
# 87.28

# %%
corrRateList = []
x = list(range(1,20,2))
for k in range(1, 20, 2):
    correctRate = 0
    corrNum = 0
    for i in test_set_2:
        res = knn2(i, k)
        if res == i[-1]:
            corrNum+=1
    correctRate = 100*corrNum/len(test_set_2)
    corrRateList.append(correctRate)

# %%
plt.plot(x, corrRateList)
x = MultipleLocator(2)
# 设置刻度间隔
ax = plt.gca()
ax.xaxis.set_major_locator(x)
plt.xlim([0, 20])
plt.ylabel("Correct Rate: %")
plt.xlabel("The num of K")
plt.show()

# %%
corrRateList = []
x = list(range(1,int(len(test_set)*0.9),2))
for k in range(1, int(len(test_set)*0.9), 2):
    correctRate = 0
    corrNum = 0
    for i in test_set_2:
        res = knn2(i, k)
        if res == i[-1]:
            corrNum+=1
    correctRate = 100*corrNum/len(test_set_2)
    corrRateList.append(correctRate)
#     print("\nwhen the k is {}, using knn the correct rate is {:.3f}%\n".format(k, correctRate))

# %%
plt.plot(x, corrRateList)
plt.ylabel("Correct Rate: %")
plt.xlabel("The num of K")
plt.show()
